# %% [markdown]
# # **Food Delivery App Recommendation System: Model Evaluation**

# %%
# Import libraries
import pandas as pd
import numpy as np
import re

# %%
# Load full_data DataFrame
full_data = pd.read_csv('~/code/Alanoudis/food-delivery-rec/data/updated_data/full_data.txt')
full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id  day_of_week order_time  \
# 0  008ab40ac0            w21z7      9390  8ace9ccb            2   01:52:03
# 1  008ce71183            w21zb      7057  f0d84faa            5   18:11:48
# 2  008ce71183            w21zb      7058  a23e4559            2   19:22:26
# 3  008ce71183            w21zb      7059  a23e4559            3   18:54:16
# 4  00ba08bab4            w21zt       347  78ce75cb            3   20:39:37
#
#   order_day  chain_id vendor_geohash cuisine_origin  avg_vendor_rating  \
# 0    3 days  aece2f12          w21z7        chinese                3.5
# 1   34 days  fc3b6153          w21zc        chinese                3.5
# 2   31 days  788f82f6          w21zb       american                3.8
# 3   18 days  788f82f6          w21zb       american                3.6
# 4   39 days  24975bf7          w21zt       american                4.5
#
#    num_products  total_order_value  \
# 0             1                0.4
# 1             2               12.8
# 2             4               14.8
# 3             4               11.6
# 4             1                3.6
#
#                                     products_ordered
# 0                                            Spicy中辣
# 1  Kway Teow Goreng with Petai & Prawns 虾仁臭豆炒河粉, ...
# 2  Tuna D'Licious, Spicy Chicken Pizza Baguette, ...
# 3  Tuna D'Licious, Chocolate Eclair, Tuna D'Licio...
# 4                                   McGriddles Feast

# %% [markdown]
# # **1. Feature Engineering: day_of_week, order_time, and order_day**

# %% [markdown]
# ## 1.1) 1️⃣🕐 **day_of_week**
#
# Type: numeric (0–6) or categorical
# Meaning: weekday the order was placed on
#
# ✅ Recommended feature engineering:
#
# Add categorical and binary features that capture weekly patterns.

# %%
# Ensure day_of_week is integer in range [0–6]
full_data['day_of_week'] = pd.to_numeric(full_data['day_of_week'], errors='coerce').astype('Int64')
full_data = full_data[full_data['day_of_week'].between(0, 6, inclusive='both')]

# Drop any existing dow_* columns if re-running
dow_cols = [c for c in full_data.columns if re.fullmatch(r'dow_[0-6]', c)]
if dow_cols:
    full_data = full_data.drop(columns=dow_cols)

# One-hot encode day_of_week
day_dummies = pd.get_dummies(full_data['day_of_week'].astype(int), prefix='dow')
day_dummies = day_dummies.reindex(columns=[f'dow_{i}' for i in range(7)], fill_value=0)

# Weekend flag
full_data['is_weekend'] = full_data['day_of_week'].isin([5, 6]).astype(int)

# Merge and ensure no duplicate column names
full_data = pd.concat([full_data, day_dummies], axis=1)
full_data = full_data.loc[:, ~full_data.columns.duplicated()]

full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id  day_of_week  \
# 0  008ab40ac0            w21z7      9390  8ace9ccb            2
# 1  008ce71183            w21zb      7057  f0d84faa            5
# 2  008ce71183            w21zb      7058  a23e4559            2
# 3  008ce71183            w21zb      7059  a23e4559            3
# 4  00ba08bab4            w21zt       347  78ce75cb            3
#
#            order_time order_day  chain_id vendor_geohash cuisine_origin  ...  \
# 0 1900-01-01 01:52:03    3 days  aece2f12          w21z7        chinese  ...
# 1 1900-01-01 18:11:48   34 days  fc3b6153          w21zc        chinese  ...
# 2 1900-01-01 19:22:26   31 days  788f82f6          w21zb       american  ...
# 3 1900-01-01 18:54:16   18 days  788f82f6          w21zb       american  ...
# 4 1900-01-01 20:39:37   39 days  24975bf7          w21zt       american  ...
#
#    meal_of_day  order_hour_sin  order_hour_cos  dow_0  dow_1  dow_2  dow_3  \
# 0   late_night        0.258819    9.659258e-01  False  False   True  False
# 1       dinner       -1.000000   -1.836970e-16  False  False  False  False
# 2       dinner       -0.965926    2.588190e-01  False  False   True  False
# 3       dinner       -1.000000   -1.836970e-16  False  False  False   True
# 4       dinner       -0.866025    5.000000e-01  False  False  False   True
#
#    dow_4  dow_5  dow_6
# 0  False  False  False
# 1  False   True  False
# 2  False  False  False
# 3  False  False  False
# 4  False  False  False
#
# [5 rows x 26 columns]

# %% [markdown]
# ✅ Useful for:
# - Capturing weekly habits (e.g., “orders more on Fridays”)
# - Analyzing order frequency by weekday

# %% [markdown]
# ## 1.2) 2️⃣⏰ **order_time**
#
# Type: string like '18:11:48'
# Meaning: time of order during the day
#
# ✅ Recommended feature engineering:
#
# Extract hour, meal period, and optionally a sin/cos time encoding (cyclical representation).

# %%
# convert to datetime.time
full_data['order_time'] = pd.to_datetime(full_data['order_time'], format='%H:%M:%S', errors='coerce')

# extract hour
full_data['order_hour'] = full_data['order_time'].dt.hour

# categorize into meal periods
def meal_of_day(h):
    if 5 <= h < 11:
        return 'breakfast'
    elif 11 <= h < 16:
        return 'lunch'
    elif 16 <= h < 22:
        return 'dinner'
    else:
        return 'late_night'

full_data['meal_of_day'] = full_data['order_hour'].apply(meal_of_day)

# optional: cyclical encoding for time-based models
import numpy as np
full_data['order_hour_sin'] = np.sin(2 * np.pi * full_data['order_hour'] / 24)
full_data['order_hour_cos'] = np.cos(2 * np.pi * full_data['order_hour'] / 24)

# %% [markdown]
# ✅ Useful for:
# - Understanding time-of-day preferences
# - Clustering orders by meal time
# - Feature input for time-aware models

# %% [markdown]
# ## 1.3) 3️⃣📅 **order_day**
# Type: string like "85 days"
# Meaning: how many days from a reference start (maybe relative or absolute)
#
# ✅ Recommended feature engineering:
#
# Convert it to numeric or datetime — it’s essential for sorting chronologically.

# %%
# Convert everything to string, strip ' days', then back to int
full_data['order_day'] = (
    full_data['order_day']
    .astype(str)
    .str.replace(' days', '', regex=False)
    .str.replace(' day', '', regex=False)
    .astype(float)   # some datasets include floats
    .astype(int)
)

# %%
# Test output
print(full_data['order_day'].head())
print(full_data['order_day'].dtype)
# Out:
# 0     3
# 1    34
# 2    31
# 3    18
# 4    39
# Name: order_day, dtype: int64
# int64

# %% [markdown]
# # 🧪 A. Model Evaluation Plan (using train/test split)

# %% [markdown]
# ## 1️⃣ Test and train data

# %% [markdown]
# ### 🧩 Step 1. Understand what you’re predicting
#
# You’re doing a food delivery recommendation model — that means:
#
# “Given a user’s past orders, predict what vendors they’ll order from next.”
#
# So, the split should mimic a real-world timeline:
#
# Train: past user behavior (earlier orders)
#
# Test: future unseen orders

# %% [markdown]
# ### ⚙️ Step 2. Choose the right split strategy
# #### **🎯 Option A — Temporal Split (recommended)**
#
# Best for behavioral data where orders have a time sequence.
#
# Steps:
#
# Convert order_day or actual order timestamp to datetime.
#
# Sort all orders by date per user.
#
# Split each user’s orders chronologically (e.g., 80% train, 20% test).
#
# This ensures:
#
# The model learns from older orders.
#
# You test it on realistic “future” behavior.

# %%
# clean or convert order_day if needed
full_data['order_day'] = pd.to_timedelta(full_data['order_day'].str.replace(' days','')).dt.days

def temporal_split(df, test_ratio=0.2):
    train_list, test_list = [], []
    for _, group in df.groupby('customer_id'):
        group = group.sort_values('order_day')
        n_test = max(1, int(len(group) * test_ratio))
        test = group.tail(n_test)
        train = group.drop(test.index)
        train_list.append(train)
        test_list.append(test)
    return pd.concat(train_list), pd.concat(test_list)

train_df, test_df = temporal_split(full_data, test_ratio=0.2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 # clean or convert order_day if needed
# ----> 2 full_data['order_day'] = pd.to_timedelta(full_data['order_day'].str.replace(' days','')).dt.days
#       4 def temporal_split(df, test_ratio=0.2):
#       5     train_list, test_list = [], []
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/core/generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/core/accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/core/strings/accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/core/strings/accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!
