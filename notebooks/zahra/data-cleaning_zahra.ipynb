# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#!pip install implicit
from scipy.sparse import csr_matrix
from sklearn.preprocessing import StandardScaler
from implicit.als import AlternatingLeastSquares

import re

# %%
big_data_path = "../../data/raw_data/orders_sg100k.txt"
big_data = pd.read_csv(big_data_path, sep=',', encoding='utf-8')
big_data.head()
# Out:
#    Unnamed: 0 customer_id geohash  order_id vendor_id    product_id  \
# 0           0  1ba124d4e5   w21z7         0  212753d2  783e85338f1c
# 1           1  1ba124d4e5   w21z7         0  212753d2  084ab73246e6
# 2           2  1ba124d4e5   w21z7         0  212753d2  30eba3cc2676
# 3           3  1ba124d4e5   w21z7         0  212753d2  3910309eea60
# 4           4  1ba124d4e5   w21z7         0  212753d2  20049fb602cb
#
#    day_of_week order_time order_day
# 0            0   12:03:29   85 days
# 1            0   12:03:29   85 days
# 2            0   12:03:29   85 days
# 3            0   12:03:29   85 days
# 4            0   12:03:29   85 days

# %% [markdown]
# # 1. *Data Cleaning*

# %%
big_data.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# ### 1.1 Import products and vendors

# %%
file_path2 = "../../data/raw_data/products_sg.txt"
products = pd.read_csv(file_path2)
# Drop the unnecessary index column
products.drop(columns=['Unnamed: 0'], inplace=True)
# Multiply price by 1000 to make it more interpretable
unit_price = products['unit_price'] * 1000
products['unit_price'] = unit_price
products.head()
# Out:
#   vendor_id    product_id                                            name  \
# 0  15bbf316  59099e089514                       Meat & Seafood Combo 海鲜套餐
# 1  e7b24dc0  52e1017fdbd9                      Sausage Egg McMuffin® Meal
# 2  e7b24dc0  fcb7110cd932             Scrambled Egg Burger w Chicken Meal
# 3  7112a20b  d3e7708c2bc9                                    Maguro Sushi
# 4  6137ef21  bf0d5ac0e03c  Family Meal - Prosp Chic TwLEVMx2 + ChBurgerHM
#
#    unit_price
# 0         3.6
# 1         2.4
# 2         2.4
# 3         1.2
# 4        10.0

# %%
file_path3 = "../../data/raw_data/vendors_sg.txt"
vendors = pd.read_csv(file_path3)
# Drop the unnecessary index column
vendors.drop(columns=['Unnamed: 0'], inplace=True)
vendors.head()
# Out:
#   vendor_id  chain_id geohash primary_cuisine
# 0  b160c319  d2786168   w21z6         mexican
# 1  9c8f010e  d2786168   w21ze         mexican
# 2  03eb25e1  5055ab25   w21ze     bak kut teh
# 3  3613129a  8984acb6   w23b1         italian
# 4  0946c9e5  1e3a2913   w21z4     bak kut teh

# %% [markdown]
# ### 1.2 Merge Into One Dataframe

# %%
# Step 1: Merge orders with products on vendor_id and product_id
orders_products = big_data.merge(products, on=['vendor_id', 'product_id'], how='left')

# Step 2: Merge the result with vendors on vendor_id
full_data = orders_products.merge(vendors, on='vendor_id', how='left')

# Preview the final merged dataset
full_data.head()
# Out:
#   customer_id geohash_x  order_id vendor_id    product_id  day_of_week  \
# 0  1ba124d4e5     w21z7         0  212753d2  783e85338f1c            0
# 1  1ba124d4e5     w21z7         0  212753d2  084ab73246e6            0
# 2  1ba124d4e5     w21z7         0  212753d2  30eba3cc2676            0
# 3  1ba124d4e5     w21z7         0  212753d2  3910309eea60            0
# 4  1ba124d4e5     w21z7         0  212753d2  20049fb602cb            0
#
#   order_time order_day                              name  unit_price  \
# 0   12:03:29   85 days  201. Japanese Garlic Karaage Don         6.0
# 1   12:03:29   85 days           204. Chicken Cutlet Don         6.8
# 2   12:03:29   85 days            206. Beef Sukiyaki Don         6.8
# 3   12:03:29   85 days   209. Japanese Beef Yakiniku Don         6.8
# 4   12:03:29   85 days          210. Teriyaki Salmon Don         8.0
#
#    chain_id geohash_y primary_cuisine
# 0  66c9978d     w21z7           ramen
# 1  66c9978d     w21z7           ramen
# 2  66c9978d     w21z7           ramen
# 3  66c9978d     w21z7           ramen
# 4  66c9978d     w21z7           ramen

# %%
# Rename geohash_x to customer_geohash and geohash_y to vendor_geohash
full_data.rename(columns={'geohash_x': 'customer_geohash', 'geohash_y': 'vendor_geohash'}, inplace=True)
full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id    product_id  day_of_week  \
# 0  1ba124d4e5            w21z7         0  212753d2  783e85338f1c            0
# 1  1ba124d4e5            w21z7         0  212753d2  084ab73246e6            0
# 2  1ba124d4e5            w21z7         0  212753d2  30eba3cc2676            0
# 3  1ba124d4e5            w21z7         0  212753d2  3910309eea60            0
# 4  1ba124d4e5            w21z7         0  212753d2  20049fb602cb            0
#
#   order_time order_day                              name  unit_price  \
# 0   12:03:29   85 days  201. Japanese Garlic Karaage Don         6.0
# 1   12:03:29   85 days           204. Chicken Cutlet Don         6.8
# 2   12:03:29   85 days            206. Beef Sukiyaki Don         6.8
# 3   12:03:29   85 days   209. Japanese Beef Yakiniku Don         6.8
# 4   12:03:29   85 days          210. Teriyaki Salmon Don         8.0
#
#    chain_id vendor_geohash primary_cuisine
# 0  66c9978d          w21z7           ramen
# 1  66c9978d          w21z7           ramen
# 2  66c9978d          w21z7           ramen
# 3  66c9978d          w21z7           ramen
# 4  66c9978d          w21z7           ramen

# %% [markdown]
# ### 1.3 NaN values [will be revisited]

# %%
# For now, we will drop the null values
full_data.isnull().sum()
# Out:
# customer_id             0
# customer_geohash        0
# order_id                0
# vendor_id               0
# product_id              0
# day_of_week             0
# order_time              0
# order_day               0
# name                    1
# unit_price              1
# chain_id            14827
# vendor_geohash          0
# primary_cuisine         0
# dtype: int64

# %%
n_nan = full_data['chain_id'].isna().sum()
ratio_nan = n_nan / len(full_data)
print('NaN count:', n_nan, ' | ratio:', f'{ratio_nan:.2%}')

# عيّنة سريعة للمراجعة
display(full_data[full_data['chain_id'].isna()].head(10))
# Out:
# NaN count: 14827  | ratio: 14.83%
#    customer_id customer_geohash  order_id vendor_id    product_id  \
# 5   f374c8c54c            w21zt         1  21830106  f245bdf79350
# 6   f374c8c54c            w21zt         1  21830106  146127be77d4
# 7   f374c8c54c            w21zt         1  21830106  6c108c0fb2b9
# 8   f374c8c54c            w21zt         1  21830106  da422c7836e1
# 9   f374c8c54c            w21zt         1  21830106  01110c80a0fa
# 10  f374c8c54c            w21zt         1  21830106  5289a6f50a7b
# 11  f374c8c54c            w21zt         1  21830106  64a268be5f2e
# 12  f374c8c54c            w21zt         1  21830106  adf53ab3befe
# 13  2e7276ad3a            w21z6         2  ee4f2ee0  2c349859aa69
# 14  2e7276ad3a            w21z6         2  ee4f2ee0  a3e4aac0520d
#
#     day_of_week order_time order_day                      name  unit_price  \
# 5             4   19:03:03   61 days  Chicken Cutlet with Rice         2.0
# 6             4   19:03:03   61 days              Chicken Chop         2.8
# 7             4   19:03:03   61 days   Chicken Wings with Rice         1.6
# 8             4   19:03:03   61 days       Saba Fish with Rice         2.4
# 9             4   19:03:03   61 days    Chicken Chop with Rice         2.0
# 10            4   19:03:03   61 days    Tomato Sauce Spaghetti         2.0
# 11            4   19:03:03   61 days              Grilled Fish         3.6
# 12            4   19:03:03   61 days              Fish & Chips         2.8
# 13            0   18:08:42    8 days      V7. Beef Noodle Soup         4.0
# 14            0   18:08:42    8 days         V12. Summer Rolls         4.0
#
#    chain_id vendor_geohash primary_cuisine
# 5       NaN          w21zt         western
# 6       NaN          w21zt         western
# 7       NaN          w21zt         western
# 8       NaN          w21zt         western
# 9       NaN          w21zt         western
# 10      NaN          w21zt         western
# 11      NaN          w21zt         western
# 12      NaN          w21zt         western
# 13      NaN          w21z7      vietnamese
# 14      NaN          w21z7      vietnamese

# %%
# ننسخ البيانات عشان نشتغل عليها
df = full_data.copy()

# (أ) نبني mapping من vendor_id -> chain_id المعروف (نأخذ الـ mode في حال التكرار)
known = df.dropna(subset=['chain_id'])
vendor_to_chain = (
    known.groupby('vendor_id')['chain_id']
         .agg(lambda s: s.mode().iloc[0])  # الأكثر تكرارًا لضبط أي ضجيج
)

# (ب) نملأ القيم الناقصة من هذا الـ mapping
df['chain_id_filled'] = df['chain_id'].copy()
df['chain_id_filled'] = df['chain_id_filled'].fillna(df['vendor_id'].map(vendor_to_chain))

# (ج) ما بقي NaN بعد الخطوة السابقة نعتبره stand-alone -> chain_id = vendor_id
solo_mask = df['chain_id_filled'].isna()
df.loc[solo_mask, 'chain_id_filled'] = df.loc[solo_mask, 'vendor_id']
df['standalone_assumption'] = solo_mask  # عشان نعرف مين اتعبّى بهذه الفرضية

# %%
# يجب أن يكون لكل vendor_id قيمة chain_id واحدة بعد التعبئة
per_vendor_unique = df.groupby('vendor_id')['chain_id_filled'].nunique()
violations = per_vendor_unique[per_vendor_unique > 1]
print('Vendors with >1 chain_id after filling:', len(violations))

# إحصائية بسيطة: كم سلسلة لها أكثر من فرع، وكم stand-alone
branches_per_chain = df.groupby('chain_id_filled')['vendor_id'].nunique()
print('Chains with multiple branches:', (branches_per_chain > 1).sum())
print('Stand-alone vendors (filled as vendor_id):', df['standalone_assumption'].sum())
# Out:
# Vendors with >1 chain_id after filling: 0
# Chains with multiple branches: 670
# Stand-alone vendors (filled as vendor_id): 14827

# %%
full_data['chain_id'] = df['chain_id_filled']

# %%
full_data.isna().sum()
# Out:
# customer_id         0
# customer_geohash    0
# order_id            0
# vendor_id           0
# product_id          0
# day_of_week         0
# order_time          0
# order_day           0
# name                1
# unit_price          1
# chain_id            0
# vendor_geohash      0
# primary_cuisine     0
# dtype: int64

# %%
print(full_data['unit_price'].isna().value_counts())
# Out:
# unit_price
# False    100000
# True          1
# Name: count, dtype: int64

# %%
rows_with_na = full_data[full_data.isna().any(axis=1)]
print(rows_with_na)
# Out:
#       customer_id customer_geohash  order_id vendor_id    product_id  \
# 27540  f869fc7f2d            w21zt     13407  a06f1cbf  1cc4fc0888d2
#
#        day_of_week order_time order_day name  unit_price  chain_id  \
# 27540            1   11:56:42   44 days  NaN         NaN  f24465fd
#
#       vendor_geohash primary_cuisine
# 27540          w21zt         chinese

# %%
# Since it's one row, I'll drop it
full_data = full_data.dropna()
full_data.isna().sum()
# Out:
# customer_id         0
# customer_geohash    0
# order_id            0
# vendor_id           0
# product_id          0
# day_of_week         0
# order_time          0
# order_day           0
# name                0
# unit_price          0
# chain_id            0
# vendor_geohash      0
# primary_cuisine     0
# dtype: int64

# %% [markdown]
# # *2. Feature Engineering*

# %% [markdown]
# ### 2.1 Categorize Cuisines

# %%
global_cuisine_category = {
    "japanese": "japanese",
    "ramen": "japanese",
    "sushi": "japanese",

    "chinese": "chinese",
    "dim sum": "chinese",
    "mala xiang guo": "chinese",
    "mala soups": "chinese",
    "hokkien mee": "chinese",
    "noodles": "chinese",
    "tea": "chinese",

    "indian": "indian",
    "curry": "indian",

    "thai": "thai",

    "vietnamese": "vietnamese",
    "pho": "vietnamese",

    "singaporean": "singaporean",
    "chicken rice": "singaporean",
    "ban mian": "singaporean",
    "yong tau foo": "singaporean",

    "indonesian": "indonesian",
    "ayam penyet": "indonesian",

    "malaysian": "malaysian",
    "nasi lemak": "malaysian",
    "roti prata": "malaysian",

    "american": "american",
    "burgers": "american",
    "sandwiches": "american",
    "grill": "american",
    "fries": "american",
    "fast food": "american",

    "italian": "italian",
    "pizza": "italian",
    "pasta": "italian",

    "french": "french",
    "german": "german",
    "spanish": "spanish",
    "mexican": "mexican",
    "turkish": "turkish",
    "lebanese": "lebanese",

    # Reassign rice-based dishes
    "rice dishes": "asian",
    "fried rice": "asian",
    "porridge": "asian",

    # Everything else defaults to snacks
}

# %%
full_data['cuisine_origin'] = full_data['primary_cuisine'].str.strip().map(global_cuisine_category)
full_data['cuisine_origin'].fillna('snacks', inplace=True)
# Out:
# /tmp/ipykernel_110572/605251586.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   full_data['cuisine_origin'].fillna('snacks', inplace=True)

# %%
print(full_data[['primary_cuisine', 'cuisine_origin']].drop_duplicates().sort_values(by='primary_cuisine'))
# Out:
#      primary_cuisine cuisine_origin
# 3347       acai bowl         snacks
# 66          american       american
# 51             asian         snacks
# 170      ayam penyet     indonesian
# 2915     bak kut teh         snacks
# ...              ...            ...
# 92        vegetarian         snacks
# 13        vietnamese     vietnamese
# 5            western         snacks
# 5098           wraps         snacks
# 657     yong tau foo    singaporean
#
# [77 rows x 2 columns]

# %%
# DROP PRIMARY CUISINE COLUMN
full_data.drop(columns=['primary_cuisine'], inplace=True)
full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id    product_id  day_of_week  \
# 0  1ba124d4e5            w21z7         0  212753d2  783e85338f1c            0
# 1  1ba124d4e5            w21z7         0  212753d2  084ab73246e6            0
# 2  1ba124d4e5            w21z7         0  212753d2  30eba3cc2676            0
# 3  1ba124d4e5            w21z7         0  212753d2  3910309eea60            0
# 4  1ba124d4e5            w21z7         0  212753d2  20049fb602cb            0
#
#   order_time order_day                              name  unit_price  \
# 0   12:03:29   85 days  201. Japanese Garlic Karaage Don         6.0
# 1   12:03:29   85 days           204. Chicken Cutlet Don         6.8
# 2   12:03:29   85 days            206. Beef Sukiyaki Don         6.8
# 3   12:03:29   85 days   209. Japanese Beef Yakiniku Don         6.8
# 4   12:03:29   85 days          210. Teriyaki Salmon Don         8.0
#
#    chain_id vendor_geohash cuisine_origin
# 0  66c9978d          w21z7       japanese
# 1  66c9978d          w21z7       japanese
# 2  66c9978d          w21z7       japanese
# 3  66c9978d          w21z7       japanese
# 4  66c9978d          w21z7       japanese

# %%
full_data.head(25)
# Out:
#    customer_id customer_geohash  order_id vendor_id    product_id  \
# 0   1ba124d4e5            w21z7         0  212753d2  783e85338f1c
# 1   1ba124d4e5            w21z7         0  212753d2  084ab73246e6
# 2   1ba124d4e5            w21z7         0  212753d2  30eba3cc2676
# 3   1ba124d4e5            w21z7         0  212753d2  3910309eea60
# 4   1ba124d4e5            w21z7         0  212753d2  20049fb602cb
# 5   f374c8c54c            w21zt         1  21830106  f245bdf79350
# 6   f374c8c54c            w21zt         1  21830106  146127be77d4
# 7   f374c8c54c            w21zt         1  21830106  6c108c0fb2b9
# 8   f374c8c54c            w21zt         1  21830106  da422c7836e1
# 9   f374c8c54c            w21zt         1  21830106  01110c80a0fa
# 10  f374c8c54c            w21zt         1  21830106  5289a6f50a7b
# 11  f374c8c54c            w21zt         1  21830106  64a268be5f2e
# 12  f374c8c54c            w21zt         1  21830106  adf53ab3befe
# 13  2e7276ad3a            w21z6         2  ee4f2ee0  2c349859aa69
# 14  2e7276ad3a            w21z6         2  ee4f2ee0  a3e4aac0520d
# 15  2e7276ad3a            w21z6         2  ee4f2ee0  b47b2a83502a
# 16  2e7276ad3a            w21z6         2  ee4f2ee0  4e1d649b81a5
# 17  2e7276ad3a            w21z6         3  b62d39b7  60a5baff060c
# 18  2e7276ad3a            w21z6         3  b62d39b7  ad485fc36ebe
# 19  2e7276ad3a            w21z6         3  b62d39b7  d732733afc92
# 20  2e7276ad3a            w21z6         4  e33ad7ec  5bb2e3772724
# 21  2e7276ad3a            w21z6         4  e33ad7ec  cbe8ace5c352
# 22  2e7276ad3a            w21z6         4  e33ad7ec  ff6a45fa52e6
# 23  2e7276ad3a            w21z6         4  e33ad7ec  bc5f3e4a7234
# 24  2e7276ad3a            w21z6         5  642370bd  75bbdbbcc37e
#
#     day_of_week order_time order_day                              name  \
# 0             0   12:03:29   85 days  201. Japanese Garlic Karaage Don
# 1             0   12:03:29   85 days           204. Chicken Cutlet Don
# 2             0   12:03:29   85 days            206. Beef Sukiyaki Don
# 3             0   12:03:29   85 days   209. Japanese Beef Yakiniku Don
# 4             0   12:03:29   85 days          210. Teriyaki Salmon Don
# 5             4   19:03:03   61 days          Chicken Cutlet with Rice
# 6             4   19:03:03   61 days                      Chicken Chop
# 7             4   19:03:03   61 days           Chicken Wings with Rice
# 8             4   19:03:03   61 days               Saba Fish with Rice
# 9             4   19:03:03   61 days            Chicken Chop with Rice
# 10            4   19:03:03   61 days            Tomato Sauce Spaghetti
# 11            4   19:03:03   61 days                      Grilled Fish
# 12            4   19:03:03   61 days                      Fish & Chips
# 13            0   18:08:42    8 days              V7. Beef Noodle Soup
# 14            0   18:08:42    8 days                 V12. Summer Rolls
# 15            0   18:08:42    8 days                 V13. Spring Rolls
# 16            0   18:08:42    8 days        V15. Vietnamese Pork Belly
# 17            2   19:05:15   59 days                           Diavola
# 18            2   19:05:15   59 days                   Cinque Formaggi
# 19            2   19:05:15   59 days              Linguine Al Granchio
# 20            3   20:13:08   81 days                       House Salad
# 21            3   20:13:08   81 days                 Da Paolo Dolcetto
# 22            3   20:13:08   81 days                Valrhona Choc Cake
# 23            3   20:13:08   81 days                        Bruschetta
# 24            0   19:14:49   29 days                              Coke
#
#     unit_price  chain_id vendor_geohash cuisine_origin
# 0          6.0  66c9978d          w21z7       japanese
# 1          6.8  66c9978d          w21z7       japanese
# 2          6.8  66c9978d          w21z7       japanese
# 3          6.8  66c9978d          w21z7       japanese
# 4          8.0  66c9978d          w21z7       japanese
# 5          2.0  21830106          w21zt         snacks
# 6          2.8  21830106          w21zt         snacks
# 7          1.6  21830106          w21zt         snacks
# 8          2.4  21830106          w21zt         snacks
# 9          2.0  21830106          w21zt         snacks
# 10         2.0  21830106          w21zt         snacks
# 11         3.6  21830106          w21zt         snacks
# 12         2.8  21830106          w21zt         snacks
# 13         4.0  ee4f2ee0          w21z7     vietnamese
# 14         4.0  ee4f2ee0          w21z7     vietnamese
# 15         4.0  ee4f2ee0          w21z7     vietnamese
# 16         4.4  ee4f2ee0          w21z7     vietnamese
# 17        11.2  67761f45          w21z3        italian
# 18        11.2  67761f45          w21z3        italian
# 19        12.4  67761f45          w21z3        italian
# 20         7.6  bf06469c          w21z6        italian
# 21        18.0  bf06469c          w21z6        italian
# 22         5.6  bf06469c          w21z6        italian
# 23         6.8  bf06469c          w21z6        italian
# 24         1.2  642370bd          w21z6         indian

# %% [markdown]
# ### 2.2 Dish Name Cleaning

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'\d+\.', '', text)         # Remove leading numbers like "204."
    text = re.sub(r'[^\w\s]', '', text)       # Remove punctuation
    text = re.sub(r'\d+', '', text)           # Remove remaining numbers
    text = text.strip()
    return text

full_data['name_cleaned'] = full_data['name'].fillna('').apply(clean_text)

# %%
full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id    product_id  day_of_week  \
# 0  1ba124d4e5            w21z7         0  212753d2  783e85338f1c            0
# 1  1ba124d4e5            w21z7         0  212753d2  084ab73246e6            0
# 2  1ba124d4e5            w21z7         0  212753d2  30eba3cc2676            0
# 3  1ba124d4e5            w21z7         0  212753d2  3910309eea60            0
# 4  1ba124d4e5            w21z7         0  212753d2  20049fb602cb            0
#
#   order_time order_day                              name  unit_price  \
# 0   12:03:29   85 days  201. Japanese Garlic Karaage Don         6.0
# 1   12:03:29   85 days           204. Chicken Cutlet Don         6.8
# 2   12:03:29   85 days            206. Beef Sukiyaki Don         6.8
# 3   12:03:29   85 days   209. Japanese Beef Yakiniku Don         6.8
# 4   12:03:29   85 days          210. Teriyaki Salmon Don         8.0
#
#    chain_id vendor_geohash cuisine_origin                 name_cleaned
# 0  66c9978d          w21z7       japanese  japanese garlic karaage don
# 1  66c9978d          w21z7       japanese           chicken cutlet don
# 2  66c9978d          w21z7       japanese            beef sukiyaki don
# 3  66c9978d          w21z7       japanese   japanese beef yakiniku don
# 4  66c9978d          w21z7       japanese          teriyaki salmon don

# %%
full_data['name'] = full_data['name_cleaned']
full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id    product_id  day_of_week  \
# 0  1ba124d4e5            w21z7         0  212753d2  783e85338f1c            0
# 1  1ba124d4e5            w21z7         0  212753d2  084ab73246e6            0
# 2  1ba124d4e5            w21z7         0  212753d2  30eba3cc2676            0
# 3  1ba124d4e5            w21z7         0  212753d2  3910309eea60            0
# 4  1ba124d4e5            w21z7         0  212753d2  20049fb602cb            0
#
#   order_time order_day                         name  unit_price  chain_id  \
# 0   12:03:29   85 days  japanese garlic karaage don         6.0  66c9978d
# 1   12:03:29   85 days           chicken cutlet don         6.8  66c9978d
# 2   12:03:29   85 days            beef sukiyaki don         6.8  66c9978d
# 3   12:03:29   85 days   japanese beef yakiniku don         6.8  66c9978d
# 4   12:03:29   85 days          teriyaki salmon don         8.0  66c9978d
#
#   vendor_geohash cuisine_origin                 name_cleaned
# 0          w21z7       japanese  japanese garlic karaage don
# 1          w21z7       japanese           chicken cutlet don
# 2          w21z7       japanese            beef sukiyaki don
# 3          w21z7       japanese   japanese beef yakiniku don
# 4          w21z7       japanese          teriyaki salmon don

# %%
# DROP PRODUCT NAME COLUMN
full_data.drop(columns=['name_cleaned'], inplace=True)
full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id    product_id  day_of_week  \
# 0  1ba124d4e5            w21z7         0  212753d2  783e85338f1c            0
# 1  1ba124d4e5            w21z7         0  212753d2  084ab73246e6            0
# 2  1ba124d4e5            w21z7         0  212753d2  30eba3cc2676            0
# 3  1ba124d4e5            w21z7         0  212753d2  3910309eea60            0
# 4  1ba124d4e5            w21z7         0  212753d2  20049fb602cb            0
#
#   order_time order_day                         name  unit_price  chain_id  \
# 0   12:03:29   85 days  japanese garlic karaage don         6.0  66c9978d
# 1   12:03:29   85 days           chicken cutlet don         6.8  66c9978d
# 2   12:03:29   85 days            beef sukiyaki don         6.8  66c9978d
# 3   12:03:29   85 days   japanese beef yakiniku don         6.8  66c9978d
# 4   12:03:29   85 days          teriyaki salmon don         8.0  66c9978d
#
#   vendor_geohash cuisine_origin
# 0          w21z7       japanese
# 1          w21z7       japanese
# 2          w21z7       japanese
# 3          w21z7       japanese
# 4          w21z7       japanese

# %% [markdown]
# # *3. Generating Synthetic Data: Products Rating (Out of 5 stars)*

# %% [markdown]
# - add rate based on each dish (Product)
#
# - show order frequency in the app for each customer ,
#
# - added 3 new columns (rating	,order_frequency)

# %%
# Set seed for reproducibility (optional)
np.random.seed(42)

# Total number of rows
n_rows =full_data.shape[0]
# Count UNIQUE orders per customer (not rows)
order_counts = full_data.groupby('customer_id')['order_id'].nunique()

# Map order counts back to original dataframe
full_data['order_frequency'] = full_data['customer_id'].map(order_counts)

# Define thresholds based on order frequency quartiles
high_freq_threshold = full_data['order_frequency'].quantile(0.75)
medium_freq_threshold = full_data['order_frequency'].quantile(0.50)


# Initialize rating column
ratings = np.zeros(n_rows)

# Assign ratings based on order frequency
for idx in range(n_rows):
    order_freq = full_data.iloc[idx, full_data.columns.get_loc('order_frequency')]

    if order_freq >= high_freq_threshold:
        # Most frequent orders: mostly 5 stars
        ratings[idx] = np.random.choice([5, 4, 3], p=[0.85, 0.10, 0.05])

    elif order_freq >= medium_freq_threshold:
        # Medium frequency: some lower ratings for 1, 2, 3 stars
        ratings[idx] = np.random.choice([5, 4, 3, 2, 1], p=[0.30, 0.25, 0.25, 0.15, 0.05])

    else:
        # Lower frequency: random distribution
        ratings[idx] = np.random.randint(1, 6)

# Add rating column to dataframe
full_data['product_rating'] = ratings.astype(int)

# %%
full_data.head()
# Out:
#   customer_id customer_geohash  order_id vendor_id    product_id  day_of_week  \
# 0  1ba124d4e5            w21z7         0  212753d2  783e85338f1c            0
# 1  1ba124d4e5            w21z7         0  212753d2  084ab73246e6            0
# 2  1ba124d4e5            w21z7         0  212753d2  30eba3cc2676            0
# 3  1ba124d4e5            w21z7         0  212753d2  3910309eea60            0
# 4  1ba124d4e5            w21z7         0  212753d2  20049fb602cb            0
#
#   order_time order_day                         name  unit_price  chain_id  \
# 0   12:03:29   85 days  japanese garlic karaage don         6.0  66c9978d
# 1   12:03:29   85 days           chicken cutlet don         6.8  66c9978d
# 2   12:03:29   85 days            beef sukiyaki don         6.8  66c9978d
# 3   12:03:29   85 days   japanese beef yakiniku don         6.8  66c9978d
# 4   12:03:29   85 days          teriyaki salmon don         8.0  66c9978d
#
#   vendor_geohash cuisine_origin  order_frequency  product_rating
# 0          w21z7       japanese                1               4
# 1          w21z7       japanese                1               5
# 2          w21z7       japanese                1               3
# 3          w21z7       japanese                1               5
# 4          w21z7       japanese                1               5

# %%
# Check how many orders each customer has made
order_counts = full_data.groupby('customer_id')['order_id'].nunique()
order_counts.head(25)
# Out:
# customer_id
# 00119c8178     1
# 00198e01e4     1
# 001a5689fc    36
# 0021dbb4c6     4
# 002f7ec570     2
# 002fe54ca1     3
# 0030b52084    22
# 003cc13317     4
# 0045c705e9    32
# 004e0fd447     4
# 0051933732     5
# 005ddefd24     1
# 006109a61b     1
# 00708980c0     1
# 0073ed74f4     2
# 007b0b2ec2     1
# 00815dd2fe     5
# 008ab40ac0     1
# 008cc4b494     1
# 008ce71183     5
# 008da08581     2
# 0094dd84a6     1
# 00a412ebfc     1
# 00a9d8f56e     1
# 00ba08bab4     1
# Name: order_id, dtype: int64

# %%
order_counts[order_counts >= 10]
# Out:
# customer_id
# 001a5689fc    36
# 0030b52084    22
# 0045c705e9    32
# 00eb815b37    10
# 00ef3009b8    12
#               ..
# fee62b2c10    16
# fef4c15ffa    13
# ff097b3d73    11
# ff29e59b1b    10
# ffa2807677    11
# Name: order_id, Length: 1211, dtype: int64

# %%
full_data.loc[full_data['customer_id'] == '2e7276ad3a']
# Out:
#    customer_id customer_geohash  order_id vendor_id    product_id  \
# 13  2e7276ad3a            w21z6         2  ee4f2ee0  2c349859aa69
# 14  2e7276ad3a            w21z6         2  ee4f2ee0  a3e4aac0520d
# 15  2e7276ad3a            w21z6         2  ee4f2ee0  b47b2a83502a
# 16  2e7276ad3a            w21z6         2  ee4f2ee0  4e1d649b81a5
# 17  2e7276ad3a            w21z6         3  b62d39b7  60a5baff060c
# 18  2e7276ad3a            w21z6         3  b62d39b7  ad485fc36ebe
# 19  2e7276ad3a            w21z6         3  b62d39b7  d732733afc92
# 20  2e7276ad3a            w21z6         4  e33ad7ec  5bb2e3772724
# 21  2e7276ad3a            w21z6         4  e33ad7ec  cbe8ace5c352
# 22  2e7276ad3a            w21z6         4  e33ad7ec  ff6a45fa52e6
# 23  2e7276ad3a            w21z6         4  e33ad7ec  bc5f3e4a7234
# 24  2e7276ad3a            w21z6         5  642370bd  75bbdbbcc37e
# 25  2e7276ad3a            w21z6         5  642370bd  9711e7ca7a2d
# 26  2e7276ad3a            w21z6         5  642370bd  51814e5d939d
# 27  2e7276ad3a            w21z6         5  642370bd  9d107187da25
# 28  2e7276ad3a            w21z6         5  642370bd  8a4e8323bb26
# 29  2e7276ad3a            w21z6         5  642370bd  7db655154c58
# 30  2e7276ad3a            w21z6         6  54a7bf39  badd0863a0a4
# 31  2e7276ad3a            w21z6         6  54a7bf39  badd0863a0a4
# 32  2e7276ad3a            w21z6         7  23c3cbb7  ad677f5bef34
# 33  2e7276ad3a            w21z6         7  23c3cbb7  5d7aa7018702
# 34  2e7276ad3a            w21z6         8  3c8b6666  f5e6f92bf92c
# 35  2e7276ad3a            w21z6         8  3c8b6666  5c5d7711df7f
# 36  2e7276ad3a            w21z6         8  3c8b6666  2315e3c4fa90
# 37  2e7276ad3a            w21z6         9  31883abc  8acf4a1914af
# 38  2e7276ad3a            w21z6         9  31883abc  fa32dfb08696
# 39  2e7276ad3a            w21z6        10  31883abc  2ef19eb9d40f
# 40  2e7276ad3a            w21z6        10  31883abc  8acf4a1914af
# 41  2e7276ad3a            w21z6        11  2a89ea8c  bebf56638ca4
# 42  2e7276ad3a            w21z6        12  921b38c7  1dad901b785a
# 43  2e7276ad3a            w21z6        12  921b38c7  f04b70979beb
# 44  2e7276ad3a            w21z6        12  921b38c7  3a8889ef7f9c
# 45  2e7276ad3a            w21z6        13  42112a93  d1538ead973f
# 46  2e7276ad3a            w21z6        13  42112a93  a524266327e5
# 47  2e7276ad3a            w21z6        14  389d8451  5caf54894346
# 48  2e7276ad3a            w21z6        15  573e52c0  927e371eb79a
# 49  2e7276ad3a            w21z6        16  24f02f22  146f120ce4a0
# 50  2e7276ad3a            w21z6        16  24f02f22  33001b37c085
#
#     day_of_week order_time order_day                                 name  \
# 13            0   18:08:42    8 days                   v beef noodle soup
# 14            0   18:08:42    8 days                       v summer rolls
# 15            0   18:08:42    8 days                       v spring rolls
# 16            0   18:08:42    8 days              v vietnamese pork belly
# 17            2   19:05:15   59 days                              diavola
# 18            2   19:05:15   59 days                      cinque formaggi
# 19            2   19:05:15   59 days                 linguine al granchio
# 20            3   20:13:08   81 days                          house salad
# 21            3   20:13:08   81 days                    da paolo dolcetto
# 22            3   20:13:08   81 days                   valrhona choc cake
# 23            3   20:13:08   81 days                           bruschetta
# 24            0   19:14:49   29 days                                 coke
# 25            0   19:14:49   29 days             hare pyaaz ka aloo jeera
# 26            0   19:14:49   29 days                       punjabi samosa
# 27            0   19:14:49   29 days                       butter chicken
# 28            0   19:14:49   29 days                           plain naan
# 29            0   19:14:49   29 days                    paneer makhanwala
# 30            2   20:40:24   87 days                      five guys shake
# 31            2   20:40:24   87 days                      five guys shake
# 32            6   18:15:10   70 days                       chocolate pint
# 33            6   18:15:10   70 days                         vanilla pint
# 34            5   20:03:46   55 days                        fungi risotto
# 35            5   20:03:46   55 days                               caesar
# 36            5   20:03:46   55 days                           ginger ale
# 37            4   19:25:30   75 days               green curry mild spicy
# 38            4   19:25:30   75 days        glass noodle salad mild spicy
# 39            2   18:15:00   66 days          vegetarian spring rolls pcs
# 40            2   18:15:00   66 days               green curry mild spicy
# 41            4   15:36:14   89 days     le parisien ham  butter baguette
# 42            4   07:50:41   47 days                        latte regular
# 43            4   07:50:41   47 days                          latte large
# 44            4   07:50:41   47 days  le parisien ham and butter baguette
# 45            5   20:51:59   34 days                              brisket
# 46            5   20:51:59   34 days                             goi cuon
# 47            3   18:28:03   18 days                                 coke
# 48            4   18:37:54   54 days                        original king
# 49            4   19:21:31   54 days                roasted herb potatoes
# 50            4   19:21:31   54 days                        pork souvlaki
#
#     unit_price  chain_id vendor_geohash cuisine_origin  order_frequency  \
# 13         4.0  ee4f2ee0          w21z7     vietnamese               15
# 14         4.0  ee4f2ee0          w21z7     vietnamese               15
# 15         4.0  ee4f2ee0          w21z7     vietnamese               15
# 16         4.4  ee4f2ee0          w21z7     vietnamese               15
# 17        11.2  67761f45          w21z3        italian               15
# 18        11.2  67761f45          w21z3        italian               15
# 19        12.4  67761f45          w21z3        italian               15
# 20         7.6  bf06469c          w21z6        italian               15
# 21        18.0  bf06469c          w21z6        italian               15
# 22         5.6  bf06469c          w21z6        italian               15
# 23         6.8  bf06469c          w21z6        italian               15
# 24         1.2  642370bd          w21z6         indian               15
# 25         8.4  642370bd          w21z6         indian               15
# 26         4.0  642370bd          w21z6         indian               15
# 27        11.2  642370bd          w21z6         indian               15
# 28         2.0  642370bd          w21z6         indian               15
# 29        10.8  642370bd          w21z6         indian               15
# 30         5.2  9d88026b          w21z7       american               15
# 31         5.2  9d88026b          w21z7       american               15
# 32         5.6  236a23ac          w21z6         snacks               15
# 33         5.6  236a23ac          w21z6         snacks               15
# 34        14.4  6ec38dc0          w21z6        italian               15
# 35         8.0  6ec38dc0          w21z6        italian               15
# 36         2.4  6ec38dc0          w21z6        italian               15
# 37         5.6  e4029dd4          w21z6           thai               15
# 38         6.4  e4029dd4          w21z6           thai               15
# 39         2.8  e4029dd4          w21z6           thai               15
# 40         5.6  e4029dd4          w21z6           thai               15
# 41         4.8  11697024          w21z6         snacks               15
# 42         2.8  11697024          w21z6         snacks               15
# 43         3.6  11697024          w21z6         snacks               15
# 44         4.8  11697024          w21z6         snacks               15
# 45         6.4  42112a93          w21z6     vietnamese               15
# 46         5.6  42112a93          w21z6     vietnamese               15
# 47         1.2  1c16531e          w21z7         snacks               15
# 48         6.8  65543bcd          w21z6       japanese               15
# 49         6.0  24f02f22          w21z6        italian               15
# 50        13.6  24f02f22          w21z6        italian               15
#
#     product_rating
# 13               1
# 14               2
# 15               5
# 16               5
# 17               5
# 18               4
# 19               4
# 20               4
# 21               5
# 22               3
# 23               5
# 24               5
# 25               4
# 26               4
# 27               3
# 28               5
# 29               4
# 30               3
# 31               5
# 32               3
# 33               5
# 34               5
# 35               2
# 36               1
# 37               2
# 38               4
# 39               5
# 40               3
# 41               4
# 42               5
# 43               4
# 44               5
# 45               2
# 46               5
# 47               3
# 48               4
# 49               4
# 50               4

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 full_data.to_csv("../../data/train-data/full_data100k.csv",index=False)
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/core/generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3978 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3980 formatter = DataFrameFormatter(
#    3981     frame=df,
#    3982     header=header,
#    (...)
#    3986     decimal=decimal,
#    3987 )
# -> 3989 return DataFrameRenderer(formatter).to_csv(
#    3990     path_or_buf,
#    3991     lineterminator=lineterminator,
#    3992     sep=sep,
#    3993     encoding=encoding,
#    3994     errors=errors,
#    3995     compression=compression,
#    3996     quoting=quoting,
#    3997     columns=columns,
#    3998     index_label=index_label,
#    3999     mode=mode,
#    4000     chunksize=chunksize,
#    4001     quotechar=quotechar,
#    4002     date_format=date_format,
#    4003     doublequote=doublequote,
#    4004     escapechar=escapechar,
#    4005     storage_options=storage_options,
#    4006 )
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/.pyenv/versions/food-delivery-rec/lib/python3.10/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../../data/train-data'
